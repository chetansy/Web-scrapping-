# %%
# !pip install beautifulsoup4

# %%
# !pip install requests

# %%
import sys
from bs4 import BeautifulSoup

# %%
import requests
import time

# %%
try:
    page = requests.get('https://www.cricbuzz.com/')
    
except Exception as e:
    error_type,error_obj,error_info = sys.exc_info()
    print('Error for link :', url)
    print(error_type, 'Line:', error_info.tb_lineno)
    
time.sleep(2)
soup = BeautifulSoup(page.text,'html.parser')
links = soup.find_all('div',attrs = {'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# All teams are set to play four games each at the Wankhede, DY Patil Stadium and three apiece at Brabourne and Pune
#
#
# New Zealand have lost 13 of the 16 Test series they've played against South Africa, and never won one. That could be about to change over the next 5 days
#
#
# Even though Kohli and Pant are rested for the series, India will be boosted by the return of Bumrah and Jadeja
#
#
# In order to keep the tournament going even in the case of a covid outbreak, the ICC has amended the minimum players required
#
#
# Bowlers laid the foundation before the troika of Smriti Mandhana, Harmanpreet Kaur and Mithali Raj hit fifties in chase
#
#
# As Richard Levi and Dewald Brevis cross paths in South Africa's domestic T20 tournament, what might SA's forgotten man have to share with its newest starlet?
#
#
# Australia are scheduled to play three ODIs and a solitary T20I post their marquee Test series in Pakistan next month
#
#
# ...

# %%
page_2 = requests.get('https://timesofindia.indiatimes.com')
time.sleep(2)
soup_2 = BeautifulSoup(page_2.text,'html.parser')
links_2 = soup_2.find_all('div',attrs = {'class':'cb-nws-intr'})

# %%
page_2
# Out:
# <Response [200]>

# %%
soup_2
# Out:
# <!DOCTYPE html>
# ...

# %%
for i in links_2:
    print(i.text)
    print('\n')
